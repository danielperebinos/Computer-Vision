# %%
import torch
from torch import nn as nn
from torch.utils.data import Dataset
from torch import optim
from torch.nn import functional as functional
import matplotlib.pyplot as plt
import pandas as pd

# %%
class dataset(Dataset):
    def __init__(self, path):
        self.dataset = torch.tensor(pd.read_csv(path).values)
    
    def __len__(self):
        return len(self.dataset)
    
    def __getitem__(self, index):
        return self.dataset[index, :-1], self.dataset[index, -1]

# %%
class Net(nn.Module):
    
    def __init__(self, n_features):
        super().__init__()
        self.n_features = n_features
        
        self.fc1 = nn.Linear(self.n_features, 16)
        self.fc2 = nn.Linear(16, 32)
        self.fc3 = nn.Linear(32, 1)
        
    def forward(self, x):
        out = functional.relu(self.fc1(x))
        out = functional.relu(self.fc2(out))
        out = functional.sigmoid(self.fc3(out))
        
        return out

# %%
def training_loop(n_epochs, optimizer, model, loss_fn, train_loader, test_loader, print_plot=True):
    
    train_accuracy = torch.zeros(n_epochs)
    test_accuracy = torch.zeros(n_epochs)
    
    for epoch in range(n_epochs):
        
        for example, labels in train_loader:
            
            labels = labels.unsqueeze(1)
            output = model(example.float())
            loss = loss_fn(output, labels.float())
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        with torch.no_grad():
            
            for loader, accuracy in [(train_loader, train_accuracy),(test_loader, test_accuracy)]:
                correct = 0
                total = 0
                
                for examples, labels in loader:
                    labels = labels.view(-1,1)
                    outputs = model(examples.float())
                    predicted = torch.round(outputs)
                    
                    total += labels.shape[0]
                    correct += (predicted == labels).sum()
                    
                accuracy[epoch] = correct / total
            
        if (epoch+1) % 10 ==0:
            print(f'Epoch {epoch+1})', 
                  f'Train Accuracy: {train_accuracy[epoch]}',
                  f'Test Accuracy: {test_accuracy[epoch]}')

    #If set to True, print graph of train and validation loss
    if print_plot:

        #Setting x-ticks
        epochs = range(n_epochs)

        #Ploting both curves, train and val 
        plt.plot(epochs, train_accuracy, 'g', label='Training accuracy')
        plt.plot(epochs, test_accuracy, 'b', label='Test accuracy')
        plt.title('Training and Test loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()

# %%
seed = 42
torch.manual_seed(seed)

data = dataset(r'Data/diabetes.csv')

n_samples = len(data)
n_test = int(0.2*n_samples)

train_set, test_set = torch.utils.data.random_split(data,  [n_samples-n_test, n_test])

train_loader = torch.utils.data.DataLoader(train_set, batch_size=len(train_set), shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set,batch_size=len(test_set), shuffle=True)

learning_rate = 1e-2
model = Net(len(data[0][0]))
optimizer = optim.Adam(model.parameters(),lr=learning_rate)
loss_fn = nn.BCELoss()

# %%
training_loop(
    n_epochs=500,
    optimizer=optimizer,
    model = model,
    loss_fn = loss_fn,
    print_plot=True,
    train_loader=train_loader,
    test_loader = test_loader
)
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\torch\nn\functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\torch\autograd\__init__.py:156: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 6050). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:112.)
#   allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# Epoch 10) Train Accuracy: 0.3544715344905853 Test Accuracy: 0.3464052379131317
# Epoch 20) Train Accuracy: 0.6455284357070923 Test Accuracy: 0.6666666865348816
# Epoch 30) Train Accuracy: 0.6585366129875183 Test Accuracy: 0.6666666865348816
# Epoch 40) Train Accuracy: 0.6975609660148621 Test Accuracy: 0.7124183177947998
# Epoch 50) Train Accuracy: 0.712195098400116 Test Accuracy: 0.6666666865348816
# Epoch 60) Train Accuracy: 0.7333333492279053 Test Accuracy: 0.6993464231491089
# Epoch 70) Train Accuracy: 0.7349593639373779 Test Accuracy: 0.6666666865348816
# Epoch 80) Train Accuracy: 0.725203275680542 Test Accuracy: 0.6993464231491089
# Epoch 90) Train Accuracy: 0.7382113933563232 Test Accuracy: 0.6993464231491089
# Epoch 100) Train Accuracy: 0.7414634227752686 Test Accuracy: 0.7058823704719543
# Epoch 110) Train Accuracy: 0.7512195110321045 Test Accuracy: 0.6993464231491089
# Epoch 120) Train Accuracy: 0.7479674816131592 Test Accuracy: 0.7058823704719543
# Epoch 130) Train Accuracy: 0.7284553050994873 Test Accuracy: 0.6993464231491089
# Epoch 140) Train Accuracy: 0.7512195110321045 Test Accuracy: 0.7189542651176453
# Epoch 150) Train Accuracy: 0.7577235698699951 Test Accuracy: 0.6928104758262634
# Epoch 160) Train Accuracy: 0.7560975551605225 Test Accuracy: 0.7189542651176453
# Epoch 170) Train Accuracy: 0.7560975551605225 Test Accuracy: 0.7320261597633362
# Epoch 180) Train Accuracy: 0.7512195110321045 Test Accuracy: 0.7254902124404907
# Epoch 190) Train Accuracy: 0.7495934963226318 Test Accuracy: 0.7124183177947998
# Epoch 200) Train Accuracy: 0.767479658126831 Test Accuracy: 0.7450980544090271
# Epoch 210) Train Accuracy: 0.7691056728363037 Test Accuracy: 0.7647058963775635
# Epoch 220) Train Accuracy: 0.7837398648262024 Test Accuracy: 0.7320261597633362
# Epoch 230) Train Accuracy: 0.7837398648262024 Test Accuracy: 0.7320261597633362
# Epoch 240) Train Accuracy: 0.7821138501167297 Test Accuracy: 0.7450980544090271
# Epoch 250) Train Accuracy: 0.7967479825019836 Test Accuracy: 0.758169949054718
# Epoch 260) Train Accuracy: 0.8016260266304016 Test Accuracy: 0.7450980544090271
# Epoch 270) Train Accuracy: 0.7983739972114563 Test Accuracy: 0.7450980544090271
# Epoch 280) Train Accuracy: 0.7886179089546204 Test Accuracy: 0.7385621070861816
# Epoch 290) Train Accuracy: 0.795121967792511 Test Accuracy: 0.758169949054718
# Epoch 300) Train Accuracy: 0.7983739972114563 Test Accuracy: 0.7516340017318726
# Epoch 310) Train Accuracy: 0.8065040707588196 Test Accuracy: 0.758169949054718
# Epoch 320) Train Accuracy: 0.7967479825019836 Test Accuracy: 0.7516340017318726
# Epoch 330) Train Accuracy: 0.7886179089546204 Test Accuracy: 0.7647058963775635
# Epoch 340) Train Accuracy: 0.8081300854682922 Test Accuracy: 0.758169949054718
# Epoch 350) Train Accuracy: 0.7983739972114563 Test Accuracy: 0.7647058963775635
# Epoch 360) Train Accuracy: 0.795121967792511 Test Accuracy: 0.7516340017318726
# Epoch 370) Train Accuracy: 0.8178861737251282 Test Accuracy: 0.7450980544090271
# Epoch 380) Train Accuracy: 0.7934959530830383 Test Accuracy: 0.7516340017318726
# Epoch 390) Train Accuracy: 0.8032520413398743 Test Accuracy: 0.758169949054718
# Epoch 400) Train Accuracy: 0.8178861737251282 Test Accuracy: 0.7647058963775635
# Epoch 410) Train Accuracy: 0.8195121884346008 Test Accuracy: 0.758169949054718
# Epoch 420) Train Accuracy: 0.8081300854682922 Test Accuracy: 0.7647058963775635
# Epoch 430) Train Accuracy: 0.8113821148872375 Test Accuracy: 0.7647058963775635
# Epoch 440) Train Accuracy: 0.8130081295967102 Test Accuracy: 0.7843137383460999
# Epoch 450) Train Accuracy: 0.8048780560493469 Test Accuracy: 0.758169949054718
# Epoch 460) Train Accuracy: 0.8211382031440735 Test Accuracy: 0.758169949054718
# Epoch 470) Train Accuracy: 0.8260162472724915 Test Accuracy: 0.7712418437004089
# Epoch 480) Train Accuracy: 0.8162601590156555 Test Accuracy: 0.7777777910232544
# Epoch 490) Train Accuracy: 0.8260162472724915 Test Accuracy: 0.7843137383460999
# Epoch 500) Train Accuracy: 0.8292682766914368 Test Accuracy: 0.7516340017318726

# %%
training_loop(
    n_epochs=700,
    optimizer=optimizer,
    model = model,
    loss_fn = loss_fn,
    print_plot=True,
    train_loader=train_loader,
    test_loader = test_loader
)
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\torch\nn\functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 10) Train Accuracy: 0.8325203061103821 Test Accuracy: 0.7647058963775635
# Epoch 20) Train Accuracy: 0.8260162472724915 Test Accuracy: 0.758169949054718
# Epoch 30) Train Accuracy: 0.8325203061103821 Test Accuracy: 0.7712418437004089
# Epoch 40) Train Accuracy: 0.8292682766914368 Test Accuracy: 0.7712418437004089
# Epoch 50) Train Accuracy: 0.8227642178535461 Test Accuracy: 0.7777777910232544
# Epoch 60) Train Accuracy: 0.8325203061103821 Test Accuracy: 0.7647058963775635
# Epoch 70) Train Accuracy: 0.8308942914009094 Test Accuracy: 0.7647058963775635
# Epoch 80) Train Accuracy: 0.8292682766914368 Test Accuracy: 0.7647058963775635
# Epoch 90) Train Accuracy: 0.8308942914009094 Test Accuracy: 0.7712418437004089
# Epoch 100) Train Accuracy: 0.8292682766914368 Test Accuracy: 0.7712418437004089
# Epoch 110) Train Accuracy: 0.8308942914009094 Test Accuracy: 0.7712418437004089
# Epoch 120) Train Accuracy: 0.8390243649482727 Test Accuracy: 0.758169949054718
# Epoch 130) Train Accuracy: 0.8471544981002808 Test Accuracy: 0.7777777910232544
# Epoch 140) Train Accuracy: 0.8211382031440735 Test Accuracy: 0.7647058963775635
# Epoch 150) Train Accuracy: 0.8487805128097534 Test Accuracy: 0.7777777910232544
# Epoch 160) Train Accuracy: 0.8357723355293274 Test Accuracy: 0.7647058963775635
# Epoch 170) Train Accuracy: 0.8390243649482727 Test Accuracy: 0.7712418437004089
# Epoch 180) Train Accuracy: 0.8487805128097534 Test Accuracy: 0.7712418437004089
# Epoch 190) Train Accuracy: 0.8439024686813354 Test Accuracy: 0.7712418437004089
# Epoch 200) Train Accuracy: 0.8487805128097534 Test Accuracy: 0.7712418437004089
# Epoch 210) Train Accuracy: 0.8471544981002808 Test Accuracy: 0.7712418437004089
# Epoch 220) Train Accuracy: 0.8390243649482727 Test Accuracy: 0.7777777910232544
# Epoch 230) Train Accuracy: 0.8373983502388 Test Accuracy: 0.758169949054718
# Epoch 240) Train Accuracy: 0.8471544981002808 Test Accuracy: 0.7647058963775635
# Epoch 250) Train Accuracy: 0.8487805128097534 Test Accuracy: 0.7712418437004089
# Epoch 260) Train Accuracy: 0.8439024686813354 Test Accuracy: 0.7516340017318726
# Epoch 270) Train Accuracy: 0.8390243649482727 Test Accuracy: 0.7777777910232544
# Epoch 280) Train Accuracy: 0.8471544981002808 Test Accuracy: 0.7647058963775635
# Epoch 290) Train Accuracy: 0.8373983502388 Test Accuracy: 0.7516340017318726
# Epoch 300) Train Accuracy: 0.842276394367218 Test Accuracy: 0.7516340017318726
# Epoch 310) Train Accuracy: 0.8373983502388 Test Accuracy: 0.758169949054718
# Epoch 320) Train Accuracy: 0.842276394367218 Test Accuracy: 0.7777777910232544
# Epoch 330) Train Accuracy: 0.8471544981002808 Test Accuracy: 0.758169949054718
# Epoch 340) Train Accuracy: 0.8504065275192261 Test Accuracy: 0.7516340017318726
# Epoch 350) Train Accuracy: 0.8292682766914368 Test Accuracy: 0.7647058963775635
# Epoch 360) Train Accuracy: 0.855284571647644 Test Accuracy: 0.7777777910232544
# Epoch 370) Train Accuracy: 0.8471544981002808 Test Accuracy: 0.7712418437004089
# Epoch 380) Train Accuracy: 0.8585366010665894 Test Accuracy: 0.7712418437004089
# Epoch 390) Train Accuracy: 0.8617886304855347 Test Accuracy: 0.7712418437004089
# Epoch 400) Train Accuracy: 0.8520325422286987 Test Accuracy: 0.7777777910232544
# Epoch 410) Train Accuracy: 0.8390243649482727 Test Accuracy: 0.758169949054718
# Epoch 420) Train Accuracy: 0.8325203061103821 Test Accuracy: 0.7777777910232544
# Epoch 430) Train Accuracy: 0.8471544981002808 Test Accuracy: 0.7647058963775635
# Epoch 440) Train Accuracy: 0.8585366010665894 Test Accuracy: 0.7516340017318726
# Epoch 450) Train Accuracy: 0.8536585569381714 Test Accuracy: 0.758169949054718
# Epoch 460) Train Accuracy: 0.8536585569381714 Test Accuracy: 0.7712418437004089
# Epoch 470) Train Accuracy: 0.8390243649482727 Test Accuracy: 0.7647058963775635
# Epoch 480) Train Accuracy: 0.8617886304855347 Test Accuracy: 0.7647058963775635
# Epoch 490) Train Accuracy: 0.860162615776062 Test Accuracy: 0.7516340017318726
# Epoch 500) Train Accuracy: 0.860162615776062 Test Accuracy: 0.7712418437004089
# Epoch 510) Train Accuracy: 0.8487805128097534 Test Accuracy: 0.7647058963775635
# Epoch 520) Train Accuracy: 0.8569105863571167 Test Accuracy: 0.7712418437004089
# Epoch 530) Train Accuracy: 0.8715447187423706 Test Accuracy: 0.7647058963775635
# Epoch 540) Train Accuracy: 0.8487805128097534 Test Accuracy: 0.7647058963775635
# Epoch 550) Train Accuracy: 0.8666666746139526 Test Accuracy: 0.7843137383460999
# Epoch 560) Train Accuracy: 0.855284571647644 Test Accuracy: 0.7712418437004089
# Epoch 570) Train Accuracy: 0.860162615776062 Test Accuracy: 0.7647058963775635
# Epoch 580) Train Accuracy: 0.8536585569381714 Test Accuracy: 0.7647058963775635
# Epoch 590) Train Accuracy: 0.842276394367218 Test Accuracy: 0.7777777910232544
# Epoch 600) Train Accuracy: 0.860162615776062 Test Accuracy: 0.7516340017318726
# Epoch 610) Train Accuracy: 0.8666666746139526 Test Accuracy: 0.7843137383460999
# Epoch 620) Train Accuracy: 0.8682926893234253 Test Accuracy: 0.7647058963775635
# Epoch 630) Train Accuracy: 0.860162615776062 Test Accuracy: 0.7843137383460999
# Epoch 640) Train Accuracy: 0.8682926893234253 Test Accuracy: 0.7843137383460999
# Epoch 650) Train Accuracy: 0.8406503796577454 Test Accuracy: 0.7908496856689453
# Epoch 660) Train Accuracy: 0.8585366010665894 Test Accuracy: 0.7712418437004089
# Epoch 670) Train Accuracy: 0.855284571647644 Test Accuracy: 0.7647058963775635
# Epoch 680) Train Accuracy: 0.8634146451950073 Test Accuracy: 0.7777777910232544
# Epoch 690) Train Accuracy: 0.8617886304855347 Test Accuracy: 0.7647058963775635
# Epoch 700) Train Accuracy: 0.8634146451950073 Test Accuracy: 0.7777777910232544

# %%
training_loop(
    n_epochs=360,
    optimizer=optimizer,
    model = model,
    loss_fn = loss_fn,
    print_plot=True,
    train_loader=train_loader,
    test_loader = test_loader
)
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\torch\nn\functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 10) Train Accuracy: 0.8796747922897339 Test Accuracy: 0.7777777910232544
# Epoch 20) Train Accuracy: 0.8617886304855347 Test Accuracy: 0.7712418437004089
# Epoch 30) Train Accuracy: 0.8780487775802612 Test Accuracy: 0.7843137383460999
# Epoch 40) Train Accuracy: 0.8796747922897339 Test Accuracy: 0.7712418437004089
# Epoch 50) Train Accuracy: 0.8715447187423706 Test Accuracy: 0.7647058963775635
# Epoch 60) Train Accuracy: 0.8813008069992065 Test Accuracy: 0.7843137383460999
# Epoch 70) Train Accuracy: 0.8520325422286987 Test Accuracy: 0.7712418437004089
# Epoch 80) Train Accuracy: 0.8715447187423706 Test Accuracy: 0.7647058963775635
# Epoch 90) Train Accuracy: 0.8731707334518433 Test Accuracy: 0.7647058963775635
# Epoch 100) Train Accuracy: 0.8585366010665894 Test Accuracy: 0.7777777910232544
# Epoch 110) Train Accuracy: 0.8341463208198547 Test Accuracy: 0.7777777910232544
# Epoch 120) Train Accuracy: 0.860162615776062 Test Accuracy: 0.758169949054718
# Epoch 130) Train Accuracy: 0.855284571647644 Test Accuracy: 0.7647058963775635
# Epoch 140) Train Accuracy: 0.855284571647644 Test Accuracy: 0.7843137383460999
# Epoch 150) Train Accuracy: 0.8764227628707886 Test Accuracy: 0.7712418437004089
# Epoch 160) Train Accuracy: 0.8764227628707886 Test Accuracy: 0.7712418437004089
# Epoch 170) Train Accuracy: 0.8764227628707886 Test Accuracy: 0.7647058963775635
# Epoch 180) Train Accuracy: 0.8829268217086792 Test Accuracy: 0.7712418437004089
# Epoch 190) Train Accuracy: 0.8682926893234253 Test Accuracy: 0.7647058963775635
# Epoch 200) Train Accuracy: 0.8764227628707886 Test Accuracy: 0.7843137383460999
# Epoch 210) Train Accuracy: 0.860162615776062 Test Accuracy: 0.7647058963775635
# Epoch 220) Train Accuracy: 0.8780487775802612 Test Accuracy: 0.7712418437004089
# Epoch 230) Train Accuracy: 0.8747967481613159 Test Accuracy: 0.7843137383460999
# Epoch 240) Train Accuracy: 0.8829268217086792 Test Accuracy: 0.7908496856689453
# Epoch 250) Train Accuracy: 0.8780487775802612 Test Accuracy: 0.7712418437004089
# Epoch 260) Train Accuracy: 0.8634146451950073 Test Accuracy: 0.7712418437004089
# Epoch 270) Train Accuracy: 0.8569105863571167 Test Accuracy: 0.7843137383460999
# Epoch 280) Train Accuracy: 0.8715447187423706 Test Accuracy: 0.7843137383460999
# Epoch 290) Train Accuracy: 0.8634146451950073 Test Accuracy: 0.7777777910232544
# Epoch 300) Train Accuracy: 0.8617886304855347 Test Accuracy: 0.758169949054718
# Epoch 310) Train Accuracy: 0.8747967481613159 Test Accuracy: 0.7843137383460999
# Epoch 320) Train Accuracy: 0.8764227628707886 Test Accuracy: 0.758169949054718
# Epoch 330) Train Accuracy: 0.8796747922897339 Test Accuracy: 0.7712418437004089
# Epoch 340) Train Accuracy: 0.8747967481613159 Test Accuracy: 0.758169949054718
# Epoch 350) Train Accuracy: 0.8617886304855347 Test Accuracy: 0.7843137383460999
# Epoch 360) Train Accuracy: 0.8666666746139526 Test Accuracy: 0.7647058963775635
